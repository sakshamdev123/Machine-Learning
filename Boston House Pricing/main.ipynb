# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
cols = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B - 1000", "LSTAT", "MEDV"]
data = pd.read_csv("housing.csv", names=cols, sep="\s+")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Saksh\AppData\Local\Temp\ipykernel_12640\1683798167.py:2: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv("housing.csv", names=cols, sep="\s+")

# %%
X = data[cols[:-1]]
y = data[["MEDV"]]

# %% [markdown]
# ### TAX vs MEDV plot

# %%
plt.scatter(X[["TAX"]], y)
plt.xlabel("TAX")
plt.ylabel("MEDV")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2)

# %%
l_reg = linear_model.LinearRegression()
model = l_reg.fit(X_train, y_train)

# %%
l_reg.score(X, y)
# Out:
# 0.6779664094190974
